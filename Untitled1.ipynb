# %%
from idlpy import IDL
# Out:
# IDL 9.3.0 (darwin arm64 m64).
# (c) 2026, NV5 Geospatial Solutions, Inc.
#
# Want an IDL Workbench alternative? Check out "IDL for VSCode" for a new user experience.
# https://marketplace.visualstudio.com/items?itemName=IDL.idl-for-vscode
#
# Licensed for use by: Chris Torrence
# License: L-7653597
# License expires  1-Jun-2030.

# %%
IDL.run("print,2+2")
# Out:
# '       4'
